# %% [markdown]
# # Get data from The New York Times
#
# In this notebook, we set up the functions to send and process multiple queries to the Article Search API provided by The New York Times. Each query asks for articles that contain a deaf-related phrase, such as "deaf and dumb" or "hearing-impaired". Full list of phrases below.
#
# The Article Search API returns a max of 10 results at a time. If we got 143 hits. The current offset is 0, so this means we are on the first 10 results, or the first page. If we append `&page=2` to the query, and process that response, now the offset is 10. This confirms we are on the second page. Since each page has 10 results and we have 143 hits, we will need to go through ceil(143/10) = 15 pages to get all of them.
#
# Contents:
# - Define functions
# - Set up queries
# - Get data
# - Postprocessing
#
# Import dependencies.

# %%
import os
import dateutil
import pandas as pd
#pd.options.display.max_colwidth = 100
import numpy as np
import requests
import time
import json
from ast import literal_eval
import datetime
from dateutil.relativedelta import relativedelta

# Usernames and passwords
import configparser
configs = configparser.ConfigParser()
configs.read('../../config.ini')
# Out:
# ['../../config.ini']

# %% [markdown]
# ## Define functions

# %%
def send_request(query, page):
    '''Sends a request to the NYT Archive API for given date.'''
    base_url = 'http://api.nytimes.com/svc/search/v2/articlesearch.json'
    url = base_url + '?fq=' + query + '&api-key=' + configs['NYT']['ACCESS_KEY'] + '&page=' + str(page)
    response = requests.get(url).json()
    time.sleep(6)
    return response


def parse_response(response, data):
    '''Parses and returns response as pandas data frame.'''
    
    articles = response['response']['docs'] 
    for article in articles: 
        
        # id
        data['id'].append(article['_id'])
        
        # Date
        date = dateutil.parser.parse(article['pub_date']).date()
        data['date'].append(date)
        
        # Headline
        data['headline'].append(article['headline']['main']) 
        
        # Section
        if 'section_name' in article:
            data['section'].append(article['section_name'])
        else:
            data['section'].append(None)
        
        # News desk
        if 'news_desk' in article:
            data['news_desk'].append(article['news_desk'])
        else:
            data['news_desk'].append(None)
        
        # Document type
        data['doc_type'].append(article['document_type'])
        
        # Type of material
        if 'type_of_material' in article: 
            data['material_type'].append(article['type_of_material'])
        else:
            data['material_type'].append(None)
            
        # Keywords
        keywords = [keyword['value'] for keyword in article['keywords'] if keyword['name'] == 'subject']
        data['keywords'].append(keywords)
        
        # Web URL
        if 'web_url' in article:
            data['url'].append(article['web_url'])
            
        # Author
        if 'byline' in article:
            data['byline'].append(article['byline']['original'])
        else:
            data['byline'].append(None)
            
            
def send_query(query, data, date=None):
    # If the query has already been sent, don't send again
    if query + '.csv' in os.listdir('data'): 
        print('Already have data for the term "' + query + '".\n')
        return False
    
    # If date is provided, append to query string
    query_str = queries[query]
    if date:
        query_str = query_str + date
        
    print('Querying string: ' + query_str + '\n')
    
    page_num = 0
    while True:
        response = send_request(query_str, page_num)
        offset = response['response']['meta']['offset']
        hits = response['response']['meta']['hits']
        
        if offset > hits: 
            print('Done processing results.\n')
            return True
        # If we have 2,000 hits or more, we will need to break down our query into date intervals
        elif hits >= 2000: 
            print('We have over 2,000 hits.\n')
            # Send the same query again, once for each date interval
            for date in q_dates:
                send_query(query, data, date) 
            return True
            
        print('Processing results ' + str(offset) + '—' + str(min((offset + 10), hits)) + '/' + str(hits) + '...')
        parse_response(response, data)
        page_num += 1

# %% [markdown]
# ## Set up queries

# %% [markdown]
# Our goal is to analyze the usage of deaf-related terms in *The New York Times*.
#
# The deaf-related terms:
#
# - "deaf and dumb"
# - "deaf-mute"
# - "hearing-impaired"
# - "tone deaf"
# - "deaf as a post"
# - "stone deaf"
# - "fell on deaf ears"
# - "deaf" (excluding its presence in all of the above terms)
#
# Some terms have varieties. For example, take "fell on deaf ears." Taking into consideration all of its varieties (that yielded hits when testing manually), the resulting query would be
#
# >`body:"fell on deaf ears" OR headline:"fell on deaf ears"
# OR body:"fall on deaf ears" OR headline:"fall on deaf ears"
# OR body:"falls on deaf ears"
# OR body:"fall on a deaf ear"
# OR body:"fell on a deaf ear"
# OR body:"turn a deaf ear" OR headline:"turn a deaf ear"
# OR body:"turned deaf ear" OR headline:"turned deaf ear"
# OR body:"turned a deaf ear" OR headline:"turned a deaf ear"`
#
# Construct remaining queries. I did this by checking the API manually in the browser, adding conditions one by one.
#
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq= + `query` + &api-key= + `api_key`

# %%
deaf_and_dumb = ['deaf and dumb',
                 'deaf dumb']

deaf_mute = ['deaf mute',
             'deaf and mute',
             'mute deaf',
             'mute and deaf']

fell_on_deaf_ears = ['fell on deaf ears', 
                     'fall on deaf ears', 
                     'falls on deaf ears', 
                     'fall on a deaf ear',
                     'falling on deaf ears',
                     'falling on a deaf ear',
                     'turn a deaf ear', 
                     'turned deaf ears', 
                     'turned a deaf ear',
                     'turning deaf ears',
                     'turning a deaf ear']

hearing_impaired = ['hearing impaired', 
                    'hearing impairment',
                    'impaired hearing']

tone_deaf = ['tone deaf']

deaf_as_a_post = ['deaf as a post']

stone_deaf = ['stone deaf']

deaf = ['deaf']

deaf_dumb_and_blind = ['deaf dumb and blind',
                       'deaf dumb blind', 
                       'blind deaf dumb',
                       'blind deaf and dumb',
                       'blind and deaf and dumb']

deafblind = ['deaf blind',
              'deafblind',
              'deaf and blind']

hard_of_hearing = ['hard of hearing']

# %%
phrases = {'deaf_and_dumb': deaf_and_dumb,
           'deaf_dumb_and_blind': deaf_dumb_and_blind,
           'deafblind': deafblind,
           'deaf_mute': deaf_mute,
           'hard_of_hearing': hoh,
           'hearing_impaired': hearing_impaired,
           'fell_on_deaf_ears': fell_on_deaf_ears,
           'tone_deaf': tone_deaf,
           'deaf_as_a_post': deaf_as_a_post,
           'stone_deaf': stone_deaf,
           'deaf': deaf}

# Save phrases to file
with open('data/phrases.txt', 'w') as outfile:
    json.dump(phrases, outfile)

# %% [markdown]
# Construct queries based on phrases.

# %%
queries = {phrase: (' OR ').join(['body:"' + x + '" OR headline:"' + x + '"' for x in phrases[phrase]]) for phrase in phrases.keys()}

# Edit 'deaf' query to exclude all other phrases that contain 'deaf'
queries['deaf'] = '(' + queries['deaf'] \
+ ') AND NOT (' + queries['deaf_and_dumb'] \
+ ') AND NOT (' + queries['deaf_mute'] \
+ ') AND NOT (' + queries['fell_on_deaf_ears'] \
+ ') AND NOT (' + queries['tone_deaf'] \
+ ') AND NOT (' + queries['deaf_as_a_post'] \
+ ') AND NOT (' + queries['stone_deaf'] \
+ ') AND NOT (' + queries['deaf_dumb_and_blind'] \
+ ') AND NOT (' + queries['deafblind'] + ')'

# did not get any results
# Edit 'deaf_dumb_and_blind' query to exclude 'deaf_and_dumb' and 'deafblind'
#queries['deaf_dumb_and_blind'] = '(' + queries['deaf_dumb_and_blind'] \
#+ ') AND NOT (' + queries['deaf_and_dumb'] + ')'

# Edit deafblind query to exclude deaf_dumb_and_blind
queries['deafblind'] = '(' + queries['deafblind'] \
+ ') AND NOT (' + queries['deaf_dumb_and_blind'] + ')'

queries
# Out:
# {'deaf_and_dumb': 'body:"deaf and dumb" OR headline:"deaf and dumb" OR body:"deaf dumb" OR headline:"deaf dumb"',
#  'deaf_dumb_and_blind': 'body:"deaf dumb and blind" OR headline:"deaf dumb and blind" OR body:"deaf dumb blind" OR headline:"deaf dumb blind" OR body:"blind deaf dumb" OR headline:"blind deaf dumb" OR body:"blind deaf and dumb" OR headline:"blind deaf and dumb" OR body:"blind and deaf and dumb" OR headline:"blind and deaf and dumb"',
#  'deafblind': '(body:"deaf blind" OR headline:"deaf blind" OR body:"deafblind" OR headline:"deafblind" OR body:"deaf and blind" OR headline:"deaf and blind") AND NOT (body:"deaf dumb and blind" OR headline:"deaf dumb and blind" OR body:"deaf dumb blind" OR headline:"deaf dumb blind" OR body:"blind deaf dumb" OR headline:"blind deaf dumb" OR body:"blind deaf and dumb" OR headline:"blind deaf and dumb" OR body:"blind and deaf and dumb" OR headline:"blind and deaf and dumb")',
#  'deaf_mute': 'body:"deaf mute" OR headline:"deaf mute" OR body:"deaf and mute" OR headline:"deaf and mute" OR body:"mute deaf" OR headline:"mute deaf" OR body:"mute and deaf" OR headline:"mute and deaf"',
#  'hard_of_hearing': 'body:"hard of hearing" OR headline:"hard of hearing"',
#  'hearing_impaired': 'body:"hearing impaired" OR headline:"hearing impaired" OR body:"hearing impairment" OR headline:"hearing impairment" OR body:"impaired hearing" OR headline:"impaired hearing"',
#  'fell_on_deaf_ears': 'body:"fell on deaf ears" OR headline:"fell on deaf ears" OR body:"fall on deaf ears" OR headline:"fall on deaf ears" OR body:"falls on deaf ears" OR headline:"falls on deaf ears" OR body:"fall on a deaf ear" OR headline:"fall on a deaf ear" OR body:"falling on deaf ears" OR headline:"falling on deaf ears" OR body:"falling on a deaf ear" OR headline:"falling on a deaf ear" OR body:"turn a deaf ear" OR headline:"turn a deaf ear" OR body:"turned deaf ears" OR headline:"turned deaf ears" OR body:"turned a deaf ear" OR headline:"turned a deaf ear" OR body:"turning deaf ears" OR headline:"turning deaf ears" OR body:"turning a deaf ear" OR headline:"turning a deaf ear"',
#  'tone_deaf': 'body:"tone deaf" OR headline:"tone deaf"',
#  'deaf_as_a_post': 'body:"deaf as a post" OR headline:"deaf as a post"',
#  'stone_deaf': 'body:"stone deaf" OR headline:"stone deaf"',
#  'deaf': '(body:"deaf" OR headline:"deaf") AND NOT (body:"deaf and dumb" OR headline:"deaf and dumb" OR body:"deaf dumb" OR headline:"deaf dumb") AND NOT (body:"deaf mute" OR headline:"deaf mute" OR body:"deaf and mute" OR headline:"deaf and mute" OR body:"mute deaf" OR headline:"mute deaf" OR body:"mute and deaf" OR headline:"mute and deaf") AND NOT (body:"fell on deaf ears" OR headline:"fell on deaf ears" OR body:"fall on deaf ears" OR headline:"fall on deaf ears" OR body:"falls on deaf ears" OR headline:"falls on deaf ears" OR body:"fall on a deaf ear" OR headline:"fall on a deaf ear" OR body:"falling on deaf ears" OR headline:"falling on deaf ears" OR body:"falling on a deaf ear" OR headline:"falling on a deaf ear" OR body:"turn a deaf ear" OR headline:"turn a deaf ear" OR body:"turned deaf ears" OR headline:"turned deaf ears" OR body:"turned a deaf ear" OR headline:"turned a deaf ear" OR body:"turning deaf ears" OR headline:"turning deaf ears" OR body:"turning a deaf ear" OR headline:"turning a deaf ear") AND NOT (body:"tone deaf" OR headline:"tone deaf") AND NOT (body:"deaf as a post" OR headline:"deaf as a post") AND NOT (body:"stone deaf" OR headline:"stone deaf") AND NOT (body:"deaf dumb and blind" OR headline:"deaf dumb and blind" OR body:"deaf dumb blind" OR headline:"deaf dumb blind" OR body:"blind deaf dumb" OR headline:"blind deaf dumb" OR body:"blind deaf and dumb" OR headline:"blind deaf and dumb" OR body:"blind and deaf and dumb" OR headline:"blind and deaf and dumb") AND NOT (body:"deaf blind" OR headline:"deaf blind" OR body:"deafblind" OR headline:"deafblind" OR body:"deaf and blind" OR headline:"deaf and blind")'}

# %% [markdown]
# ## Get data

# %% [markdown]
# Date intervals for NYT search API are formatted as `&begin_date=20120101&end_date=20121231`. We need to format date intervals because if our query returns over 2,000 results, we can't get them all. We need to make our query smaller, and we can do that by narrowing the date interval. We will do 5-year intervals.

# %%
start, end = [datetime.datetime.strptime("1850-01-01", "%Y-%m-%d"), datetime.datetime.today()]
interval = 5 # years
dates = [(start + relativedelta(years=x)).strftime('%Y%m%d') for x in range(0, relativedelta(end, start).years + 10, interval)]
q_dates = ['&begin_date=' + start + '&end_date=' + end for start, end in zip(dates, dates[1:])]
q_dates
# Out:
# ['&begin_date=18500101&end_date=18550101',
#  '&begin_date=18550101&end_date=18600101',
#  '&begin_date=18600101&end_date=18650101',
#  '&begin_date=18650101&end_date=18700101',
#  '&begin_date=18700101&end_date=18750101',
#  '&begin_date=18750101&end_date=18800101',
#  '&begin_date=18800101&end_date=18850101',
#  '&begin_date=18850101&end_date=18900101',
#  '&begin_date=18900101&end_date=18950101',
#  '&begin_date=18950101&end_date=19000101',
#  '&begin_date=19000101&end_date=19050101',
#  '&begin_date=19050101&end_date=19100101',
#  '&begin_date=19100101&end_date=19150101',
#  '&begin_date=19150101&end_date=19200101',
#  '&begin_date=19200101&end_date=19250101',
#  '&begin_date=19250101&end_date=19300101',
#  '&begin_date=19300101&end_date=19350101',
#  '&begin_date=19350101&end_date=19400101',
#  '&begin_date=19400101&end_date=19450101',
#  '&begin_date=19450101&end_date=19500101',
#  '&begin_date=19500101&end_date=19550101',
#  '&begin_date=19550101&end_date=19600101',
#  '&begin_date=19600101&end_date=19650101',
#  '&begin_date=19650101&end_date=19700101',
#  '&begin_date=19700101&end_date=19750101',
#  '&begin_date=19750101&end_date=19800101',
#  '&begin_date=19800101&end_date=19850101',
#  '&begin_date=19850101&end_date=19900101',
#  '&begin_date=19900101&end_date=19950101',
#  '&begin_date=19950101&end_date=20000101',
#  '&begin_date=20000101&end_date=20050101',
#  '&begin_date=20050101&end_date=20100101',
#  '&begin_date=20100101&end_date=20150101',
#  '&begin_date=20150101&end_date=20200101',
#  '&begin_date=20200101&end_date=20250101']

# %% [markdown]
# Send these queries to the Archive API to create CSV tables that we save to `./data/`.

# %%
for query in list(queries.keys()):
    # Reset the global data object
    data = {'headline': [],  
            'date': [], 
            'doc_type': [],
            'material_type': [],
            'news_desk': [],
            'section': [],
            'keywords': [],
            'url': [],
            'id': [],
            'byline': []}
    
    # Send query
    got_result = send_query(query, data)
    
    # Build and save frame from data object 
    if got_result:
        data_df = pd.DataFrame(data)
        data_df['date'] = pd.to_datetime(data_df['date'])
        data_df.to_csv('data/' + query + '.csv', index=False)
        print('Saved as ' + query + '.csv.\n')
# Out:
# Already have data for the term "deaf_and_dumb".
#
# Already have data for the term "deaf_dumb_and_blind".
#
# Already have data for the term "deafblind".
#
# Already have data for the term "deaf_mute".
#
# Querying string: body:"hard of hearing" OR headline:"hard of hearing"
#
# Processing results 0—10/1245...
# Processing results 10—20/1245...
# Processing results 20—30/1245...
# Processing results 30—40/1245...
# Processing results 40—50/1245...
# Processing results 50—60/1245...
# Processing results 60—70/1245...
# Processing results 70—80/1245...
# Processing results 80—90/1245...
# Processing results 90—100/1245...
# Processing results 100—110/1245...
# Processing results 110—120/1245...
# Processing results 120—130/1245...
# Processing results 130—140/1245...
# Processing results 140—150/1245...
# Processing results 150—160/1245...
# Processing results 160—170/1245...
# Processing results 170—180/1245...
# Processing results 180—190/1245...
# Processing results 190—200/1245...
# Processing results 200—210/1245...
# Processing results 210—220/1245...
# Processing results 220—230/1245...
# Processing results 230—240/1245...
# Processing results 240—250/1245...
# Processing results 250—260/1245...
# Processing results 260—270/1245...
# Processing results 270—280/1245...
# Processing results 280—290/1245...
# Processing results 290—300/1245...
# Processing results 300—310/1245...
# Processing results 310—320/1245...
# Processing results 320—330/1245...
# Processing results 330—340/1245...
# Processing results 340—350/1245...
# Processing results 350—360/1245...
# Processing results 360—370/1245...
# Processing results 370—380/1245...
# Processing results 380—390/1245...
# Processing results 390—400/1245...
# Processing results 400—410/1245...
# Processing results 410—420/1245...
# Processing results 420—430/1245...
# Processing results 430—440/1245...
# Processing results 440—450/1245...
# Processing results 450—460/1245...
# Processing results 460—470/1245...
# Processing results 470—480/1245...
# Processing results 480—490/1245...
# Processing results 490—500/1245...
# Processing results 500—510/1245...
# Processing results 510—520/1245...
# Processing results 520—530/1245...
# Processing results 530—540/1245...
# Processing results 540—550/1245...
# Processing results 550—560/1245...
# Processing results 560—570/1245...
# Processing results 570—580/1245...
# Processing results 580—590/1245...
# Processing results 590—600/1245...
# Processing results 600—610/1245...
# Processing results 610—620/1245...
# Processing results 620—630/1245...
# Processing results 630—640/1245...
# Processing results 640—650/1245...
# Processing results 650—660/1245...
# Processing results 660—670/1245...
# Processing results 670—680/1245...
# Processing results 680—690/1245...
# Processing results 690—700/1245...
# Processing results 700—710/1245...
# Processing results 710—720/1245...
# Processing results 720—730/1245...
# Processing results 730—740/1245...
# Processing results 740—750/1245...
# Processing results 750—760/1245...
# Processing results 760—770/1245...
# Processing results 770—780/1245...
# Processing results 780—790/1245...
# Processing results 790—800/1245...
# Processing results 800—810/1245...
# Processing results 810—820/1245...
# Processing results 820—830/1245...
# Processing results 830—840/1245...
# Processing results 840—850/1245...
# Processing results 850—860/1245...
# Processing results 860—870/1245...
# Processing results 870—880/1245...
# Processing results 880—890/1245...
# Processing results 890—900/1245...
# Processing results 900—910/1245...
# Processing results 910—920/1245...
# Processing results 920—930/1245...
# Processing results 930—940/1245...
# Processing results 940—950/1245...
# Processing results 950—960/1245...
# Processing results 960—970/1245...
# Processing results 970—980/1245...
# Processing results 980—990/1245...
# Processing results 990—1000/1245...
# Processing results 1000—1010/1245...
# Processing results 1010—1020/1245...
# Processing results 1020—1030/1245...
# Processing results 1030—1040/1245...
# Processing results 1040—1050/1245...
# Processing results 1050—1060/1245...
# Processing results 1060—1070/1245...
# Processing results 1070—1080/1245...
# Processing results 1080—1090/1245...
# Processing results 1090—1100/1245...
# Processing results 1100—1110/1245...
# Processing results 1110—1120/1245...
# Processing results 1120—1130/1245...
# Processing results 1130—1140/1245...
# Processing results 1140—1150/1245...
# Processing results 1150—1160/1245...
# Processing results 1160—1170/1245...
# Processing results 1170—1180/1245...
# Processing results 1180—1190/1245...
# Processing results 1190—1200/1245...
# Processing results 1200—1210/1245...
# Processing results 1210—1220/1245...
# Processing results 1220—1230/1245...
# Processing results 1230—1240/1245...
# Processing results 1240—1245/1245...
# Done processing results.
#
# Saved as hard_of_hearing.csv.
#
# Already have data for the term "hearing_impaired".
#
# Already have data for the term "fell_on_deaf_ears".
#
# Already have data for the term "tone_deaf".
#
# Already have data for the term "deaf_as_a_post".
#
# Already have data for the term "stone_deaf".
#
# Already have data for the term "deaf".

# %% [markdown]
# Merge all dataframes into one, with True or False for whether they contain a particular phrase. This means we're setting these additional `bool` columns:
#
# - deaf_and_dumb
# - deaf_mute
# - fall_on_deaf_ears
# - hearing_impaired
# - tone_deaf
# - deaf_as_a_post
# - stone_deaf
# - deaf

# %%
final_df = pd.DataFrame(columns=data.keys())

# For each key
for key in queries.keys():
    # Read in its CSV
    df = pd.read_csv('data/' + key + '.csv')
    
    # Drop any duplicates for this term alone
    num_dupes = len(df[df['id'].duplicated()])
    if num_dupes > 0:
        print('Dropping duplicates: ' + str(num_dupes))
        df = df.drop_duplicates(subset='id')
    print('added to final_df the df for key ' + key + ' with ' + str(len(df)) + ' values')
    
    df[key] = True # Label each row of this df as belonging to that df
    final_df = pd.concat([final_df, df], axis=0) # Add the df to the final df
    final_df.reset_index(drop=True, inplace=True)

print('\nTotal values: ' + str(len(final_df)))
# Out:
# added to final_df the df for key deaf_and_dumb with 727 values
# added to final_df the df for key deaf_dumb_and_blind with 182 values
# added to final_df the df for key deafblind with 536 values
# added to final_df the df for key deaf_mute with 1120 values
# added to final_df the df for key hard_of_hearing with 1245 values
# added to final_df the df for key hearing_impaired with 1423 values
# added to final_df the df for key fell_on_deaf_ears with 1757 values
# added to final_df the df for key tone_deaf with 1739 values
# added to final_df the df for key deaf_as_a_post with 22 values
# added to final_df the df for key stone_deaf with 65 values
# Dropping duplicates: 8
# added to final_df the df for key deaf with 10824 values
#
# Total values: 19640

# %%
final_df
# Out:
#                                                 headline        date  \
# 0                              THE DEAF AND DUMB WAITER.  1885-12-03
# 1              Chad Threatens to Expel Sudanese Refugees  2006-04-14
# 2                WELFARE HOTEL CHILDREN: TOMORROW'S POOR  1987-07-16
# 3      Wal-Mart Says Oil Prices Held Down Profits for...  2005-08-16
# 4       A Space Force? The Idea May Have Merit, Some Say  2018-06-23
# ...                                                  ...         ...
# 19635                                       Alexa, Awake  2020-01-03
# 19636                    Confessions of a Dating Profile  2020-01-03
# 19637                         Parent-Teacher Association  2020-01-03
# 19638   Protecting the Rights of Those With Disabilities  2020-08-01
# 19639                Max Frankel: Dining Without the Din  2020-01-23
#
#          doc_type        material_type          news_desk       section  \
# 0         article             Archives               None      Archives
# 1         article                 News      International         World
# 2         article                 News  Metropolitan Desk      New York
# 3         article                 News           Business  Business Day
# 4         article                 News         Washington          U.S.
# ...           ...                  ...                ...           ...
# 19635  multimedia  Interactive Feature            Opinion       Opinion
# 19636  multimedia  Interactive Feature            Opinion       Opinion
# 19637  multimedia  Interactive Feature            Opinion       Opinion
# 19638     article               Letter            Letters       Opinion
# 19639     article               Letter            Letters       Opinion
#
#                                                 keywords  \
# 0                                                     []
# 1                                                     []
# 2      ['Homeless Persons', 'HOTELS AND MOTELS', 'Chi...
# 3                                    ['Company Reports']
# 4      ['Space and Astronomy', 'United States Defense...
# ...                                                  ...
# 19635              ['Privacy', 'Science and Technology']
# 19636  ['Artificial Intelligence', 'Dating and Relati...
# 19637  ['Privacy', 'Education (K-12)', 'Children and ...
# 19638  ['Disabilities', 'AMERICANS WITH DISABILITIES ...
# 19639          ['Restaurants', 'Museums', 'Food Stamps']
#
#                                                      url  \
# 0      https://www.nytimes.com/1885/12/03/archives/th...
# 1      https://www.nytimes.com/2006/04/14/world/chad-...
# 2      https://www.nytimes.com/1987/07/16/nyregion/we...
# 3      https://www.nytimes.com/2005/08/16/business/wa...
# 4      https://www.nytimes.com/2018/06/23/us/politics...
# ...                                                  ...
# 19635  https://www.nytimes.com/interactive/2020/01/03...
# 19636  https://www.nytimes.com/interactive/2020/01/03...
# 19637  https://www.nytimes.com/interactive/2020/01/03...
# 19638  https://www.nytimes.com/2020/08/01/opinion/let...
# 19639  https://www.nytimes.com/2020/01/23/opinion/let...
#
#                                                       id             byline  \
# 0      nyt://article/0074c23c-1ff6-5bc7-85d9-e56a5af3...                NaN
# 1      nyt://article/00bb19d7-2ba6-5072-8e6b-3159730d...      By Marc Lacey
# 2      nyt://article/01670df3-ae07-5eb6-8862-7bd834bf...    By Lydia Chavez
# 3      nyt://article/0175ac61-cc62-5cdc-923c-f5efb8ec...    By Roben Farzad
# 4      nyt://article/01b8b8a5-7d0c-592a-a283-a9ccd3d8...   By Helene Cooper
# ...                                                  ...                ...
# 19635  nyt://interactive/c104e18e-f797-5490-b03c-259b...    By Brian Turner
# 19636  nyt://interactive/ccaba5b4-672d-568b-9daa-b6bb...     By Eric Kaplan
# 19637  nyt://interactive/df6cd908-52b0-5851-ac81-e7b8...  By Jessica Powell
# 19638  nyt://article/a23c70a4-3518-5560-a80b-38a8292d...                NaN
# 19639  nyt://article/6b20dab0-e850-54f2-98ca-9ba87ca2...                NaN
#
#        ... deaf_dumb_and_blind deafblind deaf_mute hard_of_hearing  \
# 0      ...                 NaN       NaN       NaN             NaN
# 1      ...                 NaN       NaN       NaN             NaN
# 2      ...                 NaN       NaN       NaN             NaN
# 3      ...                 NaN       NaN       NaN             NaN
# 4      ...                 NaN       NaN       NaN             NaN
# ...    ...                 ...       ...       ...             ...
# 19635  ...                 NaN       NaN       NaN             NaN
# 19636  ...                 NaN       NaN       NaN             NaN
# 19637  ...                 NaN       NaN       NaN             NaN
# 19638  ...                 NaN       NaN       NaN             NaN
# 19639  ...                 NaN       NaN       NaN             NaN
#
#       hearing_impaired fell_on_deaf_ears tone_deaf deaf_as_a_post stone_deaf  \
# 0                  NaN               NaN       NaN            NaN        NaN
# 1                  NaN               NaN       NaN            NaN        NaN
# 2                  NaN               NaN       NaN            NaN        NaN
# 3                  NaN               NaN       NaN            NaN        NaN
# 4                  NaN               NaN       NaN            NaN        NaN
# ...                ...               ...       ...            ...        ...
# 19635              NaN               NaN       NaN            NaN        NaN
# 19636              NaN               NaN       NaN            NaN        NaN
# 19637              NaN               NaN       NaN            NaN        NaN
# 19638              NaN               NaN       NaN            NaN        NaN
# 19639              NaN               NaN       NaN            NaN        NaN
#
#        deaf
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ...     ...
# 19635  True
# 19636  True
# 19637  True
# 19638  True
# 19639  True
#
# [19640 rows x 21 columns]

# %% [markdown]
# ## Postprocessing

# %% [markdown]
# Go back through each key's column and set `NaN` to `False`.

# %%
for key in queries.keys():
    final_df[key].fillna(False, inplace=True)
final_df
# Out:
#                                                 headline        date  \
# 0                              THE DEAF AND DUMB WAITER.  1885-12-03
# 1              Chad Threatens to Expel Sudanese Refugees  2006-04-14
# 2                WELFARE HOTEL CHILDREN: TOMORROW'S POOR  1987-07-16
# 3      Wal-Mart Says Oil Prices Held Down Profits for...  2005-08-16
# 4       A Space Force? The Idea May Have Merit, Some Say  2018-06-23
# ...                                                  ...         ...
# 19635                                       Alexa, Awake  2020-01-03
# 19636                    Confessions of a Dating Profile  2020-01-03
# 19637                         Parent-Teacher Association  2020-01-03
# 19638   Protecting the Rights of Those With Disabilities  2020-08-01
# 19639                Max Frankel: Dining Without the Din  2020-01-23
#
#          doc_type        material_type          news_desk       section  \
# 0         article             Archives               None      Archives
# 1         article                 News      International         World
# 2         article                 News  Metropolitan Desk      New York
# 3         article                 News           Business  Business Day
# 4         article                 News         Washington          U.S.
# ...           ...                  ...                ...           ...
# 19635  multimedia  Interactive Feature            Opinion       Opinion
# 19636  multimedia  Interactive Feature            Opinion       Opinion
# 19637  multimedia  Interactive Feature            Opinion       Opinion
# 19638     article               Letter            Letters       Opinion
# 19639     article               Letter            Letters       Opinion
#
#                                                 keywords  \
# 0                                                     []
# 1                                                     []
# 2      ['Homeless Persons', 'HOTELS AND MOTELS', 'Chi...
# 3                                    ['Company Reports']
# 4      ['Space and Astronomy', 'United States Defense...
# ...                                                  ...
# 19635              ['Privacy', 'Science and Technology']
# 19636  ['Artificial Intelligence', 'Dating and Relati...
# 19637  ['Privacy', 'Education (K-12)', 'Children and ...
# 19638  ['Disabilities', 'AMERICANS WITH DISABILITIES ...
# 19639          ['Restaurants', 'Museums', 'Food Stamps']
#
#                                                      url  \
# 0      https://www.nytimes.com/1885/12/03/archives/th...
# 1      https://www.nytimes.com/2006/04/14/world/chad-...
# 2      https://www.nytimes.com/1987/07/16/nyregion/we...
# 3      https://www.nytimes.com/2005/08/16/business/wa...
# 4      https://www.nytimes.com/2018/06/23/us/politics...
# ...                                                  ...
# 19635  https://www.nytimes.com/interactive/2020/01/03...
# 19636  https://www.nytimes.com/interactive/2020/01/03...
# 19637  https://www.nytimes.com/interactive/2020/01/03...
# 19638  https://www.nytimes.com/2020/08/01/opinion/let...
# 19639  https://www.nytimes.com/2020/01/23/opinion/let...
#
#                                                       id             byline  \
# 0      nyt://article/0074c23c-1ff6-5bc7-85d9-e56a5af3...                NaN
# 1      nyt://article/00bb19d7-2ba6-5072-8e6b-3159730d...      By Marc Lacey
# 2      nyt://article/01670df3-ae07-5eb6-8862-7bd834bf...    By Lydia Chavez
# 3      nyt://article/0175ac61-cc62-5cdc-923c-f5efb8ec...    By Roben Farzad
# 4      nyt://article/01b8b8a5-7d0c-592a-a283-a9ccd3d8...   By Helene Cooper
# ...                                                  ...                ...
# 19635  nyt://interactive/c104e18e-f797-5490-b03c-259b...    By Brian Turner
# 19636  nyt://interactive/ccaba5b4-672d-568b-9daa-b6bb...     By Eric Kaplan
# 19637  nyt://interactive/df6cd908-52b0-5851-ac81-e7b8...  By Jessica Powell
# 19638  nyt://article/a23c70a4-3518-5560-a80b-38a8292d...                NaN
# 19639  nyt://article/6b20dab0-e850-54f2-98ca-9ba87ca2...                NaN
#
#        ...  deaf_dumb_and_blind  deafblind  deaf_mute  hard_of_hearing  \
# 0      ...                False      False      False            False
# 1      ...                False      False      False            False
# 2      ...                False      False      False            False
# 3      ...                False      False      False            False
# 4      ...                False      False      False            False
# ...    ...                  ...        ...        ...              ...
# 19635  ...                False      False      False            False
# 19636  ...                False      False      False            False
# 19637  ...                False      False      False            False
# 19638  ...                False      False      False            False
# 19639  ...                False      False      False            False
#
#        hearing_impaired  fell_on_deaf_ears  tone_deaf  deaf_as_a_post  \
# 0                 False              False      False           False
# 1                 False              False      False           False
# 2                 False              False      False           False
# 3                 False              False      False           False
# 4                 False              False      False           False
# ...                 ...                ...        ...             ...
# 19635             False              False      False           False
# 19636             False              False      False           False
# 19637             False              False      False           False
# 19638             False              False      False           False
# 19639             False              False      False           False
#
#        stone_deaf   deaf
# 0           False  False
# 1           False  False
# 2           False  False
# 3           False  False
# 4           False  False
# ...           ...    ...
# 19635       False   True
# 19636       False   True
# 19637       False   True
# 19638       False   True
# 19639       False   True
#
# [19640 rows x 21 columns]

# %% [markdown]
# Some articles contain multiple phrases. For example an article may contain "deaf-mute" as well as "hearing-impaired." They currently show up as two separate rows, with duplicate values for everything except the deaf-mute and hearing-impaired columns. One row shows True in the deaf-mute column, and the other row shows True in the hearing-impaired column. We want to merge these two rows into one row where both columns show True.

# %%
if final_df['id'].duplicated().any():
    print('Duplicates: ' + str(final_df['id'].duplicated().sum()))
# Out:
# Duplicates: 1235

# %% [markdown]
# I tried to process the duplicates in the data frame like this:

# %%
final_df.groupby(df.columns[0:10].tolist(), as_index=False).max() # DOESNT WORK, DROPS TOO MANY ROWS
# Out:
#                                                 headline        date doc_type  \
# 0                                 'A Little Bit of Help'  1985-09-07  article
# 1          'Beach House,' romantic comedy at Circle Rep.  1985-03-29  article
# 2                     'Noises Off,' With Flawless Timing  1990-07-08  article
# 3                  'These People' Are Ruining Our Lives?  1990-07-01  article
# 4                 10TH ANNIVERSARY FOR 'SUMMER EVENINGS'  1985-06-09  article
# ...                                                  ...         ...      ...
# 12625  ‘Wonder Woman’ Could Be the Superhero Women in...  2017-06-04  article
# 12626                                  ‘World Wide Mind’  2011-02-15  article
# 12627  ‘Write When You Get Work’ Review: Backstreet B...  2018-11-22  article
# 12628  ‘Yellow Vests’ Riot in Paris, but Their Anger ...  2018-12-02  article
# 12629  “Rock is the medium of a generation's self‐exp...  1972-11-05  article
#
#       material_type                news_desk       section  \
# 0              News        Metropolitan Desk      New York
# 1              News             Weekend Desk       Theater
# 2              News  Westchester Weekly Desk      New York
# 3              News  Long Island Weekly Desk      New York
# 4            Review  Westchester Weekly Desk      New York
# ...             ...                      ...           ...
# 12625          News                 Business  Business Day
# 12626          Text                  Science       Science
# 12627        Review                  Weekend        Movies
# 12628          News                  Foreign         World
# 12629      Archives                     None      Archives
#
#                                                 keywords  \
# 0      ['Culture', 'Awards, Decorations and Honors', ...
# 1                                            ['Theater']
# 2                                 ['Reviews', 'Theater']
# 3      ['Social Conditions and Trends', 'Homeless Per...
# 4                                              ['Music']
# ...                                                  ...
# 12625  ['Movies', 'Women and Girls', 'Sexual Harassme...
# 12626  ['Books and Literature', 'Science and Technolo...
# 12627                                         ['Movies']
# 12628  ['Yellow Vests Movement', 'Demonstrations, Pro...
# 12629                                          ['Music']
#
#                                                      url  \
# 0      https://www.nytimes.com/1985/09/07/nyregion/ne...
# 1      https://www.nytimes.com/1985/03/29/theater/bro...
# 2      https://www.nytimes.com/1990/07/08/nyregion/th...
# 3      https://www.nytimes.com/1990/07/01/nyregion/lo...
# 4      https://www.nytimes.com/1985/06/09/nyregion/mu...
# ...                                                  ...
# 12625  https://www.nytimes.com/2017/06/04/business/me...
# 12626  https://www.nytimes.com/2011/02/15/science/15s...
# 12627  https://www.nytimes.com/2018/11/22/movies/writ...
# 12628  https://www.nytimes.com/2018/12/02/world/europ...
# 12629  https://www.nytimes.com/1972/11/05/archives/-r...
#
#                                                       id  \
# 0      nyt://article/d9a9b191-341c-5ca2-975e-7c26d0c3...
# 1      nyt://article/1d7824c8-8ec3-5af2-809b-f11b56b3...
# 2      nyt://article/6f7f506a-308a-5679-bc58-79cfa26f...
# 3      nyt://article/4c2972ff-341d-5981-9ee0-e95fa45f...
# 4      nyt://article/801429bd-4a71-5285-8a61-bf2ba672...
# ...                                                  ...
# 12625  nyt://article/234b9c6e-59ed-5dfb-a561-2939c35c...
# 12626  nyt://article/9c18470b-2b77-55bf-863a-fb55bef5...
# 12627  nyt://article/db879a75-4d65-56ff-b5ad-93ecf008...
# 12628  nyt://article/4f02b33e-94f3-5d46-9fa9-71e3c50a...
# 12629  nyt://article/040a0ccd-f2ec-5450-ac0e-45f50646...
#
#                                              byline  ...  deaf_dumb_and_blind  \
# 0      By Susan Heller Anderson and David W. Dunlap  ...                False
# 1                                      By Enid Nemy  ...                False
# 2                                    By Alvin Klein  ...                False
# 3                               By Warren Goldstein  ...                False
# 4                                 By Robert Sherman  ...                False
# ...                                             ...  ...                  ...
# 12625                              By Jim Rutenberg  ...                False
# 12626                            By Michael Chorost  ...                False
# 12627                        By Jeannette Catsoulis  ...                False
# 12628                              By Adam Nossiter  ...                False
# 12629                               By Patrick Carr  ...                False
#
#        deafblind  deaf_mute  hard_of_hearing  hearing_impaired  \
# 0          False      False            False             False
# 1          False      False            False              True
# 2          False      False            False             False
# 3          False      False             True             False
# 4          False      False            False             False
# ...          ...        ...              ...               ...
# 12625      False      False            False              True
# 12626      False      False            False             False
# 12627      False      False            False             False
# 12628      False      False            False             False
# 12629      False      False            False             False
#
#        fell_on_deaf_ears  tone_deaf  deaf_as_a_post  stone_deaf   deaf
# 0                  False      False           False       False   True
# 1                  False      False           False       False   True
# 2                  False      False           False       False   True
# 3                  False      False           False       False  False
# 4                  False      False           False       False   True
# ...                  ...        ...             ...         ...    ...
# 12625              False      False           False       False  False
# 12626              False      False           False       False   True
# 12627              False       True           False       False  False
# 12628              False      False           False       False   True
# 12629              False       True           False       False  False
#
# [12630 rows x 21 columns]

# %% [markdown]
# But it didn't work. So I copied duplicates into a separate dataframe, processed them there, removed all copies of them from final_df, then appended the processed dupes to final_df and resorted. *shrug*

# %%
# Process dupes separately
dupes = pd.concat(g for _, g in final_df.groupby('id') if len(g) > 1)
dupes
# Out:
#                                                 headline        date  \
# 4454   M. McClelland, 53; Helped Experiments In Theat...  1993-09-22
# 13930  M. McClelland, 53; Helped Experiments In Theat...  1993-09-22
# 3809           THE HARD-OF-HEARING LIKE THE THEATER, TOO  1983-08-13
# 5231           THE HARD-OF-HEARING LIKE THE THEATER, TOO  1983-08-13
# 12794          THE HARD-OF-HEARING LIKE THE THEATER, TOO  1983-08-13
# ...                                                  ...         ...
# 19572  How Architecture Could Help Us Adapt to the Pa...  2020-06-10
# 3869                                           Deaf Club  2016-04-29
# 19267                                          Deaf Club  2016-04-29
# 3975                                       ‘Magic to Do’  2011-07-25
# 18409                                      ‘Magic to Do’  2011-07-25
#
#          doc_type        material_type       news_desk     section  \
# 4454      article  Obituary; Biography        Obituary  Obituaries
# 13930     article  Obituary; Biography        Obituary  Obituaries
# 3809      article               Letter  Editorial Desk     Opinion
# 5231      article               Letter  Editorial Desk     Opinion
# 12794     article               Letter  Editorial Desk     Opinion
# ...           ...                  ...             ...         ...
# 19572  multimedia  Interactive Feature        Magazine    Magazine
# 3869   multimedia            Slideshow      T Magazine  T Magazine
# 19267  multimedia            Slideshow      T Magazine  T Magazine
# 3975   multimedia            Slideshow         Theater     Theater
# 18409  multimedia            Slideshow         Theater     Theater
#
#                                                 keywords  \
# 4454              ['Biographical Information', 'DEATHS']
# 13930             ['Biographical Information', 'DEATHS']
# 3809                             ['TERMS NOT AVAILABLE']
# 5231                             ['TERMS NOT AVAILABLE']
# 12794                            ['TERMS NOT AVAILABLE']
# ...                                                  ...
# 19572  ['Coronavirus (2019-nCoV)', 'Workplace Environ...
# 3869                               ['Deafness', 'Music']
# 19267                              ['Deafness', 'Music']
# 3975                             ['Theater', 'Deafness']
# 18409                            ['Theater', 'Deafness']
#
#                                                      url  \
# 4454   https://www.nytimes.com/1993/09/22/obituaries/...
# 13930  https://www.nytimes.com/1993/09/22/obituaries/...
# 3809   https://www.nytimes.com/1983/08/13/opinion/l-t...
# 5231   https://www.nytimes.com/1983/08/13/opinion/l-t...
# 12794  https://www.nytimes.com/1983/08/13/opinion/l-t...
# ...                                                  ...
# 19572  https://www.nytimes.com/interactive/2020/06/09...
# 3869   https://www.nytimes.com/slideshow/2016/04/29/t...
# 19267  https://www.nytimes.com/slideshow/2016/04/29/t...
# 3975   https://www.nytimes.com/slideshow/2009/02/12/t...
# 18409  https://www.nytimes.com/slideshow/2009/02/12/t...
#
#                                                       id               byline  \
# 4454   nyt://article/00742127-b642-510b-a474-a05476c5...  By Kathleen Teltsch
# 13930  nyt://article/00742127-b642-510b-a474-a05476c5...  By Kathleen Teltsch
# 3809   nyt://article/007e25b1-b68b-5bc6-ada2-350415d9...                  NaN
# 5231   nyt://article/007e25b1-b68b-5bc6-ada2-350415d9...                  NaN
# 12794  nyt://article/007e25b1-b68b-5bc6-ada2-350415d9...                  NaN
# ...                                                  ...                  ...
# 19572  nyt://interactive/e6694730-c72a-5173-ab0c-42d4...       By Kim Tingley
# 3869   nyt://slideshow/3412e8a3-2e79-5269-a752-7573ec...                  NaN
# 19267  nyt://slideshow/3412e8a3-2e79-5269-a752-7573ec...                  NaN
# 3975   nyt://slideshow/bcb62c85-d683-5d1b-b548-0a7b9b...                  NaN
# 18409  nyt://slideshow/bcb62c85-d683-5d1b-b548-0a7b9b...                  NaN
#
#        ...  deaf_dumb_and_blind  deafblind  deaf_mute  hard_of_hearing  \
# 4454   ...                False      False      False            False
# 13930  ...                False      False      False            False
# 3809   ...                False      False      False             True
# 5231   ...                False      False      False            False
# 12794  ...                False      False      False            False
# ...    ...                  ...        ...        ...              ...
# 19572  ...                False      False      False            False
# 3869   ...                False      False      False            False
# 19267  ...                False      False      False            False
# 3975   ...                False      False      False            False
# 18409  ...                False      False      False            False
#
#        hearing_impaired  fell_on_deaf_ears  tone_deaf  deaf_as_a_post  \
# 4454               True              False      False           False
# 13930             False              False      False           False
# 3809              False              False      False           False
# 5231               True              False      False           False
# 12794             False              False      False           False
# ...                 ...                ...        ...             ...
# 19572             False              False      False           False
# 3869               True              False      False           False
# 19267             False              False      False           False
# 3975               True              False      False           False
# 18409             False              False      False           False
#
#        stone_deaf   deaf
# 4454        False  False
# 13930       False   True
# 3809        False  False
# 5231        False  False
# 12794       False   True
# ...           ...    ...
# 19572       False   True
# 3869        False  False
# 19267       False   True
# 3975        False  False
# 18409       False   True
#
# [2379 rows x 21 columns]

# %% [markdown]
# Merge rows so that there is only one row for each unique id, retaining all True values. Note again that for each unique id, the only thing that differs are the columns containing the True/False values, hence us doing groupby on all the other columns so that we can apply .max() to those True/False columns.
#
# .max() works cuz True > False

# %%
dupes.reset_index(drop=True, inplace=True)
dupes_fixed = dupes.groupby(dupes.columns[0:10].tolist(), as_index=False).max()
dupes_fixed
# Out:
#                                               headline        date doc_type  \
# 0        'Beach House,' romantic comedy at Circle Rep.  1985-03-29  article
# 1                                          DRUNK AGAIN  1985-03-31  article
# 2                               HELPING THOSE HOW HELP  1985-11-24  article
# 3               HOPE IS OFFERED TO THE HARD-OF-HEARING  1985-08-18  article
# 4            LISTENERS PAY A HIGH PRICE FOR LOUD MUSIC  1990-03-18  article
# ..                                                 ...         ...      ...
# 802  ‘Nothing About Us Without Us’: 16 Moments in t...  2020-07-22  article
# 803                         ‘Singing’ With Their Hands  2012-02-11  article
# 804  ‘Switched at Birth,’ a Series Illuminating a W...  2017-01-30  article
# 805                                     ‘The Worthy’\n  2006-07-23  article
# 806                  ‘Tommy’ Is Poignantly Sentimental  1970-06-08  article
#
#     material_type                news_desk          section  \
# 0            News             Weekend Desk          Theater
# 1            News            Magazine Desk         Magazine
# 2            News             Society Desk            Style
# 3            News  Westchester Weekly Desk         New York
# 4            News    Arts and Leisure Desk             Arts
# ..            ...                      ...              ...
# 802          News          SpecialSections             U.S.
# 803          News                   Styles  Fashion & Style
# 804          News                  Culture             Arts
# 805          News               BookReview            Books
# 806      Archives                     None         Archives
#
#                                               keywords  \
# 0                                          ['Theater']
# 1                                 ['English Language']
# 2                              ['TERMS NOT AVAILABLE']
# 3                              ['TERMS NOT AVAILABLE']
# 4                                ['Music', 'Deafness']
# ..                                                 ...
# 802  ['Disabilities', 'Civil Rights and Liberties',...
# 803  ['Video Recordings and Downloads', 'Music', 'S...
# 804                                     ['Television']
# 805                           ['Books and Literature']
# 806                                                 []
#
#                                                    url  \
# 0    https://www.nytimes.com/1985/03/29/theater/bro...
# 1    https://www.nytimes.com/1985/03/31/magazine/on...
# 2    https://www.nytimes.com/1985/11/24/style/socia...
# 3    https://www.nytimes.com/1985/08/18/nyregion/we...
# 4    https://www.nytimes.com/1990/03/18/arts/sound-...
# ..                                                 ...
# 802  https://www.nytimes.com/2020/07/22/us/ada-disa...
# 803  https://www.nytimes.com/2012/02/12/fashion/sin...
# 804  https://www.nytimes.com/2017/01/30/arts/televi...
# 805  https://www.nytimes.com/2006/07/23/books/chapt...
# 806  https://www.nytimes.com/1970/06/08/archives/to...
#
#                                                     id                 byline  \
# 0    nyt://article/1d7824c8-8ec3-5af2-809b-f11b56b3...           By Enid Nemy
# 1    nyt://article/89c35a34-5440-5541-afbf-3f8f652d...      By William Safire
# 2    nyt://article/855d9f97-49c4-58d6-9640-c7bd9d2b...  By Robert E. Tomasson
# 3    nyt://article/82d141c9-c2b9-5324-bc57-1ad2021f...        By Rosalyn Fein
# 4    nyt://article/a4d01869-7cfa-5f26-9a45-019ca8aa...         By Hans Fantel
# ..                                                 ...                    ...
# 802  nyt://article/b87eb307-fda1-5fda-83c7-701dc80f...        By Julia Carmel
# 803  nyt://article/0918d106-bd33-59fe-a100-cd3f9a23...    By Austin Considine
# 804  nyt://article/70949850-b6e8-50c9-9982-1061b7f8...     By Neil Genzlinger
# 805  nyt://article/51443601-2828-54cd-bdc4-c330b652...         By Will Clarke
# 806  nyt://article/8eb71423-3640-5907-a72b-af2ee177...       By Donal Henahan
#
#      ...  deaf_dumb_and_blind  deafblind  deaf_mute  hard_of_hearing  \
# 0    ...                False      False      False            False
# 1    ...                False      False      False            False
# 2    ...                False      False      False             True
# 3    ...                False      False      False             True
# 4    ...                False      False      False            False
# ..   ...                  ...        ...        ...              ...
# 802  ...                False      False      False             True
# 803  ...                False      False      False            False
# 804  ...                False      False      False            False
# 805  ...                 True      False      False            False
# 806  ...                 True      False      False            False
#
#      hearing_impaired  fell_on_deaf_ears  tone_deaf  deaf_as_a_post  \
# 0                True              False      False           False
# 1                True              False      False           False
# 2                True              False      False           False
# 3                True              False      False           False
# 4                True              False      False           False
# ..                ...                ...        ...             ...
# 802             False              False      False           False
# 803              True              False      False           False
# 804              True              False      False           False
# 805             False              False      False           False
# 806             False              False      False           False
#
#      stone_deaf   deaf
# 0         False   True
# 1         False   True
# 2         False  False
# 3         False   True
# 4         False   True
# ..          ...    ...
# 802       False   True
# 803       False   True
# 804       False   True
# 805       False  False
# 806       False  False
#
# [807 rows x 21 columns]

# %% [markdown]
# Remove all instances of duplicates from final_df.

# %%
final_df = final_df[~final_df['id'].isin(dupes['id'])]
final_final_lol_mybad_df = pd.concat((final_df, dupes_fixed))
final_final_lol_mybad_df.reset_index(inplace=True, drop=True)
final_final_lol_mybad_df
# Out:
#                                                 headline        date doc_type  \
# 0                              THE DEAF AND DUMB WAITER.  1885-12-03  article
# 1              Chad Threatens to Expel Sudanese Refugees  2006-04-14  article
# 2                WELFARE HOTEL CHILDREN: TOMORROW'S POOR  1987-07-16  article
# 3      NEW-YORK CITY.; Union of the Liberal Societies...  1854-07-06  article
# 4                            Deaf and Dumb at Intervals.  1896-09-06  article
# ...                                                  ...         ...      ...
# 18063  ‘Nothing About Us Without Us’: 16 Moments in t...  2020-07-22  article
# 18064                         ‘Singing’ With Their Hands  2012-02-11  article
# 18065  ‘Switched at Birth,’ a Series Illuminating a W...  2017-01-30  article
# 18066                                     ‘The Worthy’\n  2006-07-23  article
# 18067                  ‘Tommy’ Is Poignantly Sentimental  1970-06-08  article
#
#       material_type          news_desk          section  \
# 0          Archives               None         Archives
# 1              News      International            World
# 2              News  Metropolitan Desk         New York
# 3          Archives               None         Archives
# 4          Archives               None         Archives
# ...             ...                ...              ...
# 18063          News    SpecialSections             U.S.
# 18064          News             Styles  Fashion & Style
# 18065          News            Culture             Arts
# 18066          News         BookReview            Books
# 18067      Archives               None         Archives
#
#                                                 keywords  \
# 0                                                     []
# 1                                                     []
# 2      ['Homeless Persons', 'HOTELS AND MOTELS', 'Chi...
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 18063  ['Disabilities', 'Civil Rights and Liberties',...
# 18064  ['Video Recordings and Downloads', 'Music', 'S...
# 18065                                     ['Television']
# 18066                           ['Books and Literature']
# 18067                                                 []
#
#                                                      url  \
# 0      https://www.nytimes.com/1885/12/03/archives/th...
# 1      https://www.nytimes.com/2006/04/14/world/chad-...
# 2      https://www.nytimes.com/1987/07/16/nyregion/we...
# 3      https://www.nytimes.com/1854/07/06/archives/ne...
# 4      https://www.nytimes.com/1896/09/06/archives/de...
# ...                                                  ...
# 18063  https://www.nytimes.com/2020/07/22/us/ada-disa...
# 18064  https://www.nytimes.com/2012/02/12/fashion/sin...
# 18065  https://www.nytimes.com/2017/01/30/arts/televi...
# 18066  https://www.nytimes.com/2006/07/23/books/chapt...
# 18067  https://www.nytimes.com/1970/06/08/archives/to...
#
#                                                       id               byline  \
# 0      nyt://article/0074c23c-1ff6-5bc7-85d9-e56a5af3...                  NaN
# 1      nyt://article/00bb19d7-2ba6-5072-8e6b-3159730d...        By Marc Lacey
# 2      nyt://article/01670df3-ae07-5eb6-8862-7bd834bf...      By Lydia Chavez
# 3      nyt://article/027c2e43-cb25-52ab-9eee-03873325...                  NaN
# 4      nyt://article/02812482-a829-5351-b560-31a87b64...                  NaN
# ...                                                  ...                  ...
# 18063  nyt://article/b87eb307-fda1-5fda-83c7-701dc80f...      By Julia Carmel
# 18064  nyt://article/0918d106-bd33-59fe-a100-cd3f9a23...  By Austin Considine
# 18065  nyt://article/70949850-b6e8-50c9-9982-1061b7f8...   By Neil Genzlinger
# 18066  nyt://article/51443601-2828-54cd-bdc4-c330b652...       By Will Clarke
# 18067  nyt://article/8eb71423-3640-5907-a72b-af2ee177...     By Donal Henahan
#
#        ...  deaf_dumb_and_blind  deafblind  deaf_mute  hard_of_hearing  \
# 0      ...                False      False      False            False
# 1      ...                False      False      False            False
# 2      ...                False      False      False            False
# 3      ...                False      False      False            False
# 4      ...                False      False      False            False
# ...    ...                  ...        ...        ...              ...
# 18063  ...                False      False      False             True
# 18064  ...                False      False      False            False
# 18065  ...                False      False      False            False
# 18066  ...                 True      False      False            False
# 18067  ...                 True      False      False            False
#
#        hearing_impaired  fell_on_deaf_ears  tone_deaf  deaf_as_a_post  \
# 0                 False              False      False           False
# 1                 False              False      False           False
# 2                 False              False      False           False
# 3                 False              False      False           False
# 4                 False              False      False           False
# ...                 ...                ...        ...             ...
# 18063             False              False      False           False
# 18064              True              False      False           False
# 18065              True              False      False           False
# 18066             False              False      False           False
# 18067             False              False      False           False
#
#        stone_deaf   deaf
# 0           False  False
# 1           False  False
# 2           False  False
# 3           False  False
# 4           False  False
# ...           ...    ...
# 18063       False   True
# 18064       False   True
# 18065       False   True
# 18066       False  False
# 18067       False  False
#
# [18068 rows x 21 columns]

# %%
print('Duplicates: ' + str(final_final_lol_mybad_df['id'].duplicated().sum()))
# Out:
# Duplicates: 0

# %%
final_final_lol_mybad_df.to_csv('data/all.csv', index=False)
